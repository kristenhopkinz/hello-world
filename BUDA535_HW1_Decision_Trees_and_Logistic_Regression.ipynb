# %% [markdown]
# <a href="https://colab.research.google.com/github/kristenhopkinz/hello-world/blob/main/BUDA535_HW1_Decision_Trees_and_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1
#
# a) Compute the Entropy for the Movie ID attribute.
#
# b) Compute the Entropy for the Format attribute.
#
# c) Compute the Entropy for the Movie Category attribute using multiway split.
#
# d) Which of the three attributes has the lowest Entropy?
#
# e) Which of the three attributes will you use for splitting at the root node?
# Briefly explain your choice.
#
# ![Screenshot 2025-03-13 at 5.40.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# # a).
# The movie ID entropy would be 0 because the MovieID's are all unique, so when split them into group, you only have one record of each where p(c0) and p(c1) = 1 or 0. For example lets take MovieID 1 and MovieID 20:
#
# **Movie ID 1:**
#
# p(c0)= 1
#
# p(c1)= 0
#
# entropy = -(1 log2 1 + 0 log2 0) = -(0+0) = **0**
#
# **Movie ID 20:**
#
# p(c0) = 0
#
# p(c1) = 1
#
# entropy = -(0 log2 0 + 1 log2 1) = (0+0) = **0**

# %% [markdown]
# # b).
# We can split the Format Atribute into 2 categories : DVD and Online, each with 10 instances
#
# **DVD:**
#
# p(c0) = 6
#
# p(c1)= 2
#
# DVD entropy = -(6/8 log2 6/8 + 2/8 log2 2/8) = 0.811278124459
#
# **Online:**
#
# p(c0) = 4
#
# p(c1) = 8
#
# Online entropy = -(4/12 log2 4/12 + 8/12 log2 8/12) = 0.918295834054
#
# **Format Entropy now that we have both entropies:**
#
# Format Entropy: (8/20 * .811) + (12/20 * .92) = **0.8764**

# %% [markdown]
# # c.
# We can split the Movie category into 3 categories: Entertainment(4), Documentaries(8), and Comedy(8):
#
# **Entertainment:**
#
# p(c0): 1
#
# p(c1): 3
#
# Entertainment Entropy: -(1/4 log2 1/4 + 3/4 log2 3/4) = 0.811278124459
#
# **Documetaries:**
#
# p(c0): 2
#
# p(c1): 6
#
# Documentaries Entropy:  -(2/8 log2 2/8 + 6/8 log2 6/8) = 0.811278124459
#
# **Comedy**
#
# p(c0): 7
#
# p(c1): 1
#
# Comedy Entropy:  -(7/8 log2 7/8 + 1/8 log2 1/8) = 0.5435644432
#
# **Movie Entropy now that we have all 3 entropies:**
#
# (4/20 * .811) + (8/20 * .811) + (8/20 * .54) = **0.7026**

# %% [markdown]
# #d.
#
# The lowest entropy was the **Movie ID** at **0**. After that the lowest entropy would be the **Movie Category** at **.7026**

# %% [markdown]
# # e.
#
# To find the best node to split at the root node we first need the overall impurity before splitting:
#
# p(c0): 10
#
# p(c1): 10
#
# overall entropy: -(10/20 log2 10/20 + 10/20 log2 10/20) = **1.0**
#
# So we can take this to help us find the information gain after splitting:
#
# IG on Movie Category: 1- .7026 = **0.2974**
#
# IG on Format: 1 - 0.8764 = **0.1236**
#
# Since the information gain is more/higher when we split by **movie category**, then that is the way we should split at the root node

# %% [markdown]
# # Part II
# ![Screenshot 2025-03-13 at 5.41.35 PM.png](data:image/png;base64,...)

# %% [markdown]
# #f.
# To calculate accuracy: correct predictions / total predictions
#
# When we look at the tree, we see if A = 0, then go to B. If B = 0, then it is +. If B = 1 then it is -. If A = 1 then go to C. If C = 0 then it is +. If C = 1 then it is -.
#
# So, when we look at the test dataset, we see that 4 classes are correct, and 1 is incorrect. so **4/5 = 80% accuracy**

# %% [markdown]
# # **Question 2**
#
# ![Screenshot 2025-03-13 at 8.07.34 PM.png](data:image/png;base64,...)
#
# # a.)
# The parameters are the **weights (w1, w2,..wd)** and the **bias (b)**

# %% [markdown]
# # b-1.)
#
# Point A looks like it's at (3,3) on the figure so we can calculate the Z score by plugging it into the function:
#
# z(point A) = 4(3) + 6(3) - 24 = **6**
#
# To find the probability that A is positive we can plug it into the decision function:
#
# σ(z) = 1/(1+e^-6) = **0.997527376843**

# %% [markdown]
# # b-2.)
#
# We need to set our function to = 0 to help us draw the decision boundry:
#
# 0 = 4x1 + 6x2 -24
#
# 6x2 = 4x1 - 24
#
# x2 = 4/6 x1 - 4 --->  x2 = 2/3x1 - 4
#
# So our slope is 2/3 and our y- intercept is 4
#
# so we have (0,4) and we need another point to connect the dot to draw our line so lets do when x2 = 0 to get the x intercept
#
# 4x1 + 6(0) - 24 ---> 24 = 4x1 ---> x1 = 6
#
# so now we have two points to draw our line: (0,4) and (6,0). AND when z > 0 it is positive (above the line), and when z < 0 it is negative (below the line).
#
# ![Screenshot 2025-03-13 at 7.42.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# # b-3)
#
# So we have 15 points. 7 positive (green) and 8 negative (red)
#
# But 3 of those points aren't classified correctly. 1 of the positives is below the line in the negative section and 2 of the negatives are above the line in the positive section.
#
# So we have 15-3 = 12 correct preidctions.
#
# So 12/15 = **80% accuracy**

# %% [markdown]
# ![Screenshot 2025-03-13 at 8.07.44 PM.png](data:image/png;base64,...)

# %% [markdown]
# # b-4).
#
# True Positives: 45
#
# True Negatives: 40
#
# False Positives: 10
#
# False Negatives: 5
#
# **Accuracy**: 40+45 / 45+40+10+5 = **85%**
#
# **Precision:** 45 / 45+10 = **82%**
#
# **Recall:**  45 / 45+5 = **90%**

# %% [markdown]
# # PROBELM 3 PROGRAMMING

# %% [markdown]
# # BUDA 535: Assignment 1: Question 3
#
# The goal of this question is to get you familiar with training and testing machine learning models with Scikit-learn library.
#
# The Pima Indians Diabetes Dataset involves predicting the onset of diabetes within 5 years in Pima Indians given medical details. The dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset.
#
# It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 768 observations with 8 input variables and 1 output variable. Missing values are believed to be encoded with zero values. The columns are as follows:
#
# ```
# Number of times pregnant.
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test.
# Diastolic blood pressure (mm Hg).
# Triceps skinfold thickness (mm).
# 2-Hour serum insulin (mu U/ml).
# Body mass index (weight in kg/(height in m)^2).
# Diabetes pedigree function.
# Age (years).
# Class variable (0 or 1).
# ```
#
# In this question, you are given the **training data** and **test data**, which are derived from the 768 observations.
#
# * Training data: https://github.com/binbenliu/Teaching/blob/main/IntroAI/data/diabetes_train.csv
#
# * Test data: https://github.com/binbenliu/Teaching/blob/main/IntroAI/data/diabetes_test.csv
#
#
# You are asked to train and test following models:
# * Decision trees https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier
# * item Logistic regression https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# After you train each  model on the **training data**, you should report following classification metrics on the **test data**: (1) accuracy, (2) precision, (3) recall, and (4) F1\_score.
#
# Also,  (1) for Decision tree model, display the decision tree you derived, and discuss how decision tree make the classifications; and (2) for Logistic regression, display the feature importance scores, namely, $w_1, w_2, ..., w_d$, and discuss what you find from the model.
#
# Your final submission should include the Python code in jupyter notebook to generate the classification results.  Your grade will **NOT** be determined by the accuracy you are able to achieve, though we encourage you to explore different learning settings (e.g., choosing the right regularization strength) to get better results. Instead, we want to see you are able to train and test machine learning models with Scikit-learn library.

# %% [markdown]
# #  Read and prepare the data
#
# Training data: https://raw.githubusercontent.com/binbenliu/Teaching/main/IntroAI/data/diabetes_train.csv
#
# Testing data: https://raw.githubusercontent.com/binbenliu/Teaching/main/IntroAI/data/diabetes_test.csv

# %%
import pandas as pd

# read training data
train_file = "https://raw.githubusercontent.com/binbenliu/Teaching/main/IntroAI/data/diabetes_train.csv"
train_df = pd.read_csv(train_file, header='infer')

# %%
train_df.head(5) #see first 5 entries
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# read test data
test_file = "https://raw.githubusercontent.com/binbenliu/Teaching/main/IntroAI/data/diabetes_test.csv"
test_df = pd.read_csv(test_file, header='infer')

# %%
test_df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           11      138             74             26      144  36.1
# 1            3      106             72              0        0  25.8
# 2            6      117             96              0        0  28.7
# 3            2       68             62             13       15  20.1
# 4            9      112             82             24        0  28.2
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.557   50        1
# 1                     0.207   27        0
# 2                     0.157   30        0
# 3                     0.257   23        0
# 4                     1.282   50        1

# %%
# train data
x_train = train_df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y_train = train_df['Outcome']

# test data
x_test = test_df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']].values
y_test = test_df['Outcome'].values

# %% [markdown]
# ## Model 1 Decision tree model
#
# ###  Specify and train your decision tree model
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier
#
# class sklearn.tree.DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth=5, min_samples_leaf=5, min_samples_split=5, max_leaf_nodes=15 )
clf = clf.fit(x_train, y_train)

# %% [markdown]
# ### Decision tree:  predict and evaluate
#
# Make predictions and get following classfication metrics:
#
# * accuracy
# * precision
# * recall
# * f1_score

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

y_pred = clf.predict(x_test)
predictions = pd.concat([test_df, pd.Series(y_pred, name= "Predicted Outome")], axis=1)
predictions[0:100]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            11      138             74             26      144  36.1
# 1             3      106             72              0        0  25.8
# 2             6      117             96              0        0  28.7
# 3             2       68             62             13       15  20.1
# 4             9      112             82             24        0  28.2
# ..          ...      ...            ...            ...      ...   ...
# 95            2       93             64             32      160  38.0
# 96            3      158             64             13      387  31.2
# 97            5      126             78             27       22  29.6
# 98           10      129             62             36        0  41.2
# ...

# %%
from sklearn.metrics import confusion_matrix

#confusion matrix to see our
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index=["actual 0", "actual 1"], columns=["predicted 0", "predicted 1"])

print("CM:")
print(cm_df)
# Out:
# CM:
#           predicted 0  predicted 1
# actual 0           80           19
# actual 1           19           36

# %%
print("Accuracy: %.2f" % accuracy_score(y_test, y_pred))

print("Precision: %.2f" % precision_score(y_test, y_pred))

print("Recall: %.2f" % recall_score(y_test, y_pred))

print("f1: %.2f" % f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.75
# Precision: 0.65
# Recall: 0.65
# f1: 0.65

# %% [markdown]
# ### Display the decision tree
# display the decision tree you derived, and discuss how decision tree make the classifications

# %%
import pydotplus
from IPython.display import Image

dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=x_train.columns,
                                class_names=['No Diabetes','Diabetes'],
                                filled=True, rounded=True,
                                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# ## Model 2 Logistic regression model
#
# ### LR: Specify and train your logistic regression model
#
# Logistic regression with regularziation
#
# \begin{equation}
# L(\mathbf{w}, b) = \frac{1}{n}\sum_{i=1}^n l\left(\sigma\left(\mathbf{w}^\top \mathbf{x}^{(i)} + b\right),  y^{(i)}\right) + \frac{\alpha}{2} \|\mathbf{w}\|^2.
# \end{equation}
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# **sklearn.linear_model.LogisticRegression**(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)

# %%
## here is your code to train the logistic regression

# %% [markdown]
# ### LR:  predict and evaluate
#
# Make predictions and get following classfication metrics:
#
# * accuracy
# * precision
# * recall
# * f1_score

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# here is your code to make prediciton and get the classfication metrics based on the trained logistic regression model

# %% [markdown]
# ### Feature importance
# display the feature importance scores, namely, $w_1, w_2, ..., w_d$, and discuss what you find from the model.

# %%
# here is your code to display the feature importance scores of your LR model
